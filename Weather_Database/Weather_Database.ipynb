# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import requests
from citipy import citipy

import time
from datetime import datetime

# Import config file using sys (I performed it this way for security purposes...
# I googled how to pull from a location other than the same folder)
import sys  
sys.path.insert(0, "/Users/KATLIN/Documents/Data Analytics/Classwork/")
import config

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

   # If the city is unique, then we will add it to the cities list.
     if city not in cities:
         cities.append(city)
#  Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | artigas
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | kavaratti
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | batagay-alyta
# Processing Record 10 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 1 | athabasca
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | gurkovo
# Processing Record 14 of Set 1 | puerto del rosario
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | quballat
# Processing Record 18 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 1 | san ignacio
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | korla
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | evanston
# Processing Record 29 of Set 1 | egvekinot
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 1 | yeppoon
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | lazaro cardenas
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 1 | mareeba
# Processing Record 43 of Set 1 | seoul
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | havelock
# Processing Record 50 of Set 1 | guiratinga
# Processing Record 1 of Set 2 | puerto escondido
# Processing Record 2 of Set 2 | clyde river
# Processing Record 3 of Set 2 | samarai
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | kasongo
# Processing Record 12 of Set 2 | myitkyina
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | nalut
# Processing Record 15 of Set 2 | beloha
# Processing Record 16 of Set 2 | clinton
# Processing Record 17 of Set 2 | te anau
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | saint anthony
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | anuradhapura
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 2 | namibe
# Processing Record 33 of Set 2 | farmington
# Processing Record 34 of Set 2 | adre
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | inhambane
# Processing Record 42 of Set 2 | paysandu
# Processing Record 43 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 2 | basco
# Processing Record 45 of Set 2 | birin
# Processing Record 46 of Set 2 | rio gallegos
# Processing Record 47 of Set 2 | kayes
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | caravelas
# Processing Record 50 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 3 | wewak
# Processing Record 2 of Set 3 | pak phanang
# Processing Record 3 of Set 3 | jalu
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | skegness
# Processing Record 6 of Set 3 | lasa
# Processing Record 7 of Set 3 | grants
# Processing Record 8 of Set 3 | comodoro rivadavia
# Processing Record 9 of Set 3 | idrinskoye
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | smithers
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | carauari
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | chapleau
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | toktogul
# Processing Record 19 of Set 3 | vallenar
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | strezhevoy
# Processing Record 22 of Set 3 | lagoa
# Processing Record 23 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | kampene
# Processing Record 26 of Set 3 | gat
# Processing Record 27 of Set 3 | verkhnevilyuysk
# Processing Record 28 of Set 3 | rodrigues alves
# Processing Record 29 of Set 3 | filingue
# Processing Record 30 of Set 3 | iqaluit
# Processing Record 31 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | hattiesburg
# Processing Record 35 of Set 3 | liku
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 3 | panzhihua
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | villa carlos paz
# Processing Record 41 of Set 3 | tessalit
# Processing Record 42 of Set 3 | pringsewu
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | tucuman
# Processing Record 47 of Set 3 | pandan
# Processing Record 48 of Set 3 | gwadar
# Processing Record 49 of Set 3 | ugoofaaru
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | fort nelson
# Processing Record 4 of Set 4 | bubaque
# Processing Record 5 of Set 4 | nouadhibou
# Processing Record 6 of Set 4 | tahta
# Processing Record 7 of Set 4 | san policarpo
# Processing Record 8 of Set 4 | benguela
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | ust-nera
# Processing Record 11 of Set 4 | nador
# Processing Record 12 of Set 4 | akyab
# Processing Record 13 of Set 4 | camocim
# Processing Record 14 of Set 4 | provideniya
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | ejido
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 4 | carlsbad
# Processing Record 21 of Set 4 | mogadishu
# Processing Record 22 of Set 4 | tigre
# Processing Record 23 of Set 4 | port elizabeth
# Processing Record 24 of Set 4 | gotsu
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | portland
# Processing Record 27 of Set 4 | deputatskiy
# Processing Record 28 of Set 4 | christchurch
# Processing Record 29 of Set 4 | khartoum
# Processing Record 30 of Set 4 | nizwa
# Processing Record 31 of Set 4 | spirit river
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | broome
# Processing Record 34 of Set 4 | popondetta
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | lancaster
# Processing Record 37 of Set 4 | gari
# Processing Record 38 of Set 4 | jinchengjiang
# City not found. Skipping...
# Processing Record 39 of Set 4 | coihaique
# Processing Record 40 of Set 4 | presidencia roque saenz pena
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | raahe
# Processing Record 43 of Set 4 | palanga
# Processing Record 44 of Set 4 | phan thiet
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | aswan
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | zelenoborskiy
# Processing Record 50 of Set 4 | ampanihy
# Processing Record 1 of Set 5 | newberry
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | half moon bay
# Processing Record 4 of Set 5 | varzea da palma
# Processing Record 5 of Set 5 | aquiraz
# Processing Record 6 of Set 5 | mishelevka
# Processing Record 7 of Set 5 | sosva
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | hervey bay
# Processing Record 12 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 5 | college
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | harstad
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | dukat
# Processing Record 19 of Set 5 | sola
# Processing Record 20 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 5 | veraval
# Processing Record 22 of Set 5 | port blair
# Processing Record 23 of Set 5 | semey
# Processing Record 24 of Set 5 | newark
# Processing Record 25 of Set 5 | saltillo
# Processing Record 26 of Set 5 | emerald
# Processing Record 27 of Set 5 | kenai
# Processing Record 28 of Set 5 | teknaf
# Processing Record 29 of Set 5 | mandiana
# Processing Record 30 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 5 | kaduna
# Processing Record 32 of Set 5 | aykhal
# Processing Record 33 of Set 5 | igarka
# Processing Record 34 of Set 5 | hobyo
# Processing Record 35 of Set 5 | labuhan
# Processing Record 36 of Set 5 | linxia
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | canutama
# Processing Record 39 of Set 5 | ostrovnoy
# Processing Record 40 of Set 5 | angren
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | vao
# Processing Record 43 of Set 5 | zaragoza
# Processing Record 44 of Set 5 | puerto narino
# Processing Record 45 of Set 5 | port moresby
# Processing Record 46 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 5 | bytow
# Processing Record 48 of Set 5 | ginir
# Processing Record 49 of Set 5 | peace river
# Processing Record 50 of Set 5 | ahuimanu
# Processing Record 1 of Set 6 | lucea
# Processing Record 2 of Set 6 | nelson
# Processing Record 3 of Set 6 | keetmanshoop
# Processing Record 4 of Set 6 | esmeraldas
# Processing Record 5 of Set 6 | tacna
# Processing Record 6 of Set 6 | abu dhabi
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | torbay
# Processing Record 9 of Set 6 | concordia
# Processing Record 10 of Set 6 | anadyr
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | nassjo
# Processing Record 13 of Set 6 | mount isa
# Processing Record 14 of Set 6 | ventsy
# Processing Record 15 of Set 6 | slave lake
# Processing Record 16 of Set 6 | lorca
# Processing Record 17 of Set 6 | stity
# Processing Record 18 of Set 6 | severnoye
# Processing Record 19 of Set 6 | nanortalik
# Processing Record 20 of Set 6 | skelleftea
# Processing Record 21 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 6 | port-cartier
# Processing Record 23 of Set 6 | kununurra
# Processing Record 24 of Set 6 | constitucion
# Processing Record 25 of Set 6 | shelburne
# Processing Record 26 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 6 | shahreza
# Processing Record 28 of Set 6 | jardim
# Processing Record 29 of Set 6 | banda aceh
# Processing Record 30 of Set 6 | sao joao da barra
# Processing Record 31 of Set 6 | thinadhoo
# Processing Record 32 of Set 6 | laguna
# Processing Record 33 of Set 6 | sembakung
# Processing Record 34 of Set 6 | buchanan
# Processing Record 35 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 6 | coracao de jesus
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | vardo
# Processing Record 39 of Set 6 | pitimbu
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | porto velho
# Processing Record 42 of Set 6 | racari
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | naze
# Processing Record 46 of Set 6 | hami
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | leszno
# Processing Record 49 of Set 6 | shubarkuduk
# Processing Record 50 of Set 6 | trairi
# Processing Record 1 of Set 7 | viedma
# Processing Record 2 of Set 7 | samandag
# Processing Record 3 of Set 7 | nuuk
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | bahia blanca
# Processing Record 6 of Set 7 | kommunisticheskiy
# Processing Record 7 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 7 | mardin
# Processing Record 10 of Set 7 | kyzyl-suu
# Processing Record 11 of Set 7 | sheridan
# Processing Record 12 of Set 7 | banyo
# Processing Record 13 of Set 7 | taltal
# Processing Record 14 of Set 7 | leningradskiy
# Processing Record 15 of Set 7 | boddam
# Processing Record 16 of Set 7 | teya
# Processing Record 17 of Set 7 | la palma
# Processing Record 18 of Set 7 | cabo san lucas
# Processing Record 19 of Set 7 | yantzaza
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | oranjemund
# Processing Record 22 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 23 of Set 7 | uyemskiy
# Processing Record 24 of Set 7 | newport
# Processing Record 25 of Set 7 | bismarck
# Processing Record 26 of Set 7 | bilma
# Processing Record 27 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 7 | doha
# Processing Record 29 of Set 7 | shu
# Processing Record 30 of Set 7 | anamur
# Processing Record 31 of Set 7 | honiara
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | mirosov
# Processing Record 34 of Set 7 | hualmay
# Processing Record 35 of Set 7 | nouakchott
# Processing Record 36 of Set 7 | bay-khaak
# Processing Record 37 of Set 7 | pedasi
# Processing Record 38 of Set 7 | kuryk
# Processing Record 39 of Set 7 | malaya vishera
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | ayan
# Processing Record 42 of Set 7 | ambon
# Processing Record 43 of Set 7 | dahuk
# Processing Record 44 of Set 7 | kodiak
# Processing Record 45 of Set 7 | point pleasant
# Processing Record 46 of Set 7 | maumere
# Processing Record 47 of Set 7 | yerbogachen
# Processing Record 48 of Set 7 | archidona
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | sao filipe
# Processing Record 1 of Set 8 | riyadh
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | pingdingshan
# Processing Record 4 of Set 8 | singtam
# Processing Record 5 of Set 8 | ternate
# Processing Record 6 of Set 8 | sompeta
# Processing Record 7 of Set 8 | pakxan
# Processing Record 8 of Set 8 | great yarmouth
# Processing Record 9 of Set 8 | andarab
# City not found. Skipping...
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | contamana
# Processing Record 13 of Set 8 | galle
# Processing Record 14 of Set 8 | shetpe
# Processing Record 15 of Set 8 | tabuk
# Processing Record 16 of Set 8 | billings
# Processing Record 17 of Set 8 | sorong
# Processing Record 18 of Set 8 | porosozero
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | sorland
# Processing Record 21 of Set 8 | fonte boa
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | beringovskiy
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | sisimiut
# Processing Record 26 of Set 8 | wadi musa
# Processing Record 27 of Set 8 | geraldton
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 8 | maues
# Processing Record 31 of Set 8 | suluq
# Processing Record 32 of Set 8 | luderitz
# Processing Record 33 of Set 8 | san miguel
# Processing Record 34 of Set 8 | berlevag
# Processing Record 35 of Set 8 | roald
# Processing Record 36 of Set 8 | amapa
# Processing Record 37 of Set 8 | bonavista
# Processing Record 38 of Set 8 | maragogi
# Processing Record 39 of Set 8 | ossora
# Processing Record 40 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 8 | belyy yar
# Processing Record 42 of Set 8 | masvingo
# Processing Record 43 of Set 8 | spornoye
# Processing Record 44 of Set 8 | kimbe
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | voyvozh
# Processing Record 47 of Set 8 | thompson
# Processing Record 48 of Set 8 | kamaishi
# Processing Record 49 of Set 8 | muros
# Processing Record 50 of Set 8 | dunedin
# Processing Record 1 of Set 9 | piracanjuba
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | barlad
# Processing Record 4 of Set 9 | havre-saint-pierre
# Processing Record 5 of Set 9 | saint george
# Processing Record 6 of Set 9 | darnah
# Processing Record 7 of Set 9 | maridi
# Processing Record 8 of Set 9 | nantucket
# Processing Record 9 of Set 9 | joao pinheiro
# Processing Record 10 of Set 9 | rumoi
# Processing Record 11 of Set 9 | bakel
# Processing Record 12 of Set 9 | guerrero negro
# Processing Record 13 of Set 9 | marakkanam
# Processing Record 14 of Set 9 | dongsheng
# Processing Record 15 of Set 9 | lorengau
# Processing Record 16 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 9 | maksatikha
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | nyurba
# Processing Record 20 of Set 9 | santiago
# Processing Record 21 of Set 9 | gravdal
# Processing Record 22 of Set 9 | sarangani
# Processing Record 23 of Set 9 | vynohradove
# Processing Record 24 of Set 9 | gouyave
# Processing Record 25 of Set 9 | mazamari
# Processing Record 26 of Set 9 | romanovka
# Processing Record 27 of Set 9 | koslan
# Processing Record 28 of Set 9 | churapcha
# Processing Record 29 of Set 9 | makakilo city
# Processing Record 30 of Set 9 | lapua
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | norrtalje
# Processing Record 33 of Set 9 | sechura
# Processing Record 34 of Set 9 | los llanos de aridane
# Processing Record 35 of Set 9 | krasnoselkup
# Processing Record 36 of Set 9 | aripuana
# Processing Record 37 of Set 9 | stornoway
# Processing Record 38 of Set 9 | micheweni
# Processing Record 39 of Set 9 | ballina
# Processing Record 40 of Set 9 | ardakan
# Processing Record 41 of Set 9 | acarau
# Processing Record 42 of Set 9 | simpang
# Processing Record 43 of Set 9 | mondlo
# Processing Record 44 of Set 9 | shanghai
# Processing Record 45 of Set 9 | botwood
# Processing Record 46 of Set 9 | keuruu
# Processing Record 47 of Set 9 | qui nhon
# Processing Record 48 of Set 9 | faya
# Processing Record 49 of Set 9 | rock springs
# Processing Record 50 of Set 9 | sistranda
# Processing Record 1 of Set 10 | riachao das neves
# Processing Record 2 of Set 10 | kodinsk
# Processing Record 3 of Set 10 | kyabe
# Processing Record 4 of Set 10 | novobirilyussy
# Processing Record 5 of Set 10 | kudahuvadhoo
# Processing Record 6 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 10 | necochea
# Processing Record 8 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 10 | fairhope
# Processing Record 10 of Set 10 | tumpat
# Processing Record 11 of Set 10 | karagaylinskiy
# Processing Record 12 of Set 10 | pointe michel
# Processing Record 13 of Set 10 | maniitsoq
# Processing Record 14 of Set 10 | afsin
# Processing Record 15 of Set 10 | adelanto
# Processing Record 16 of Set 10 | rio grande
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | pareora
# Processing Record 19 of Set 10 | caborca
# Processing Record 20 of Set 10 | piacabucu
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | ewa beach
# Processing Record 23 of Set 10 | inuvik
# Processing Record 24 of Set 10 | ariquemes
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | auki
# Processing Record 27 of Set 10 | chicama
# Processing Record 28 of Set 10 | gidole
# Processing Record 29 of Set 10 | yar-sale
# Processing Record 30 of Set 10 | gien
# Processing Record 31 of Set 10 | panzos
# Processing Record 32 of Set 10 | teocaltiche
# Processing Record 33 of Set 10 | bani
# Processing Record 34 of Set 10 | king city
# Processing Record 35 of Set 10 | gerash
# Processing Record 36 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | arman
# Processing Record 38 of Set 10 | tautira
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | pavlohrad
# Processing Record 41 of Set 10 | lebedinyy
# Processing Record 42 of Set 10 | mocuba
# Processing Record 43 of Set 10 | glucholazy
# Processing Record 44 of Set 10 | pontianak
# Processing Record 45 of Set 10 | inta
# Processing Record 46 of Set 10 | poum
# Processing Record 47 of Set 10 | resistencia
# Processing Record 48 of Set 10 | ouesso
# Processing Record 49 of Set 10 | turayf
# Processing Record 50 of Set 10 | ojinaga
# Processing Record 1 of Set 11 | klyuchi
# Processing Record 2 of Set 11 | kamenka
# Processing Record 3 of Set 11 | kibre mengist
# Processing Record 4 of Set 11 | tukrah
# Processing Record 5 of Set 11 | diamantino
# Processing Record 6 of Set 11 | ginda
# Processing Record 7 of Set 11 | birao
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | hornepayne
# Processing Record 10 of Set 11 | les ponts-de-ce
# Processing Record 11 of Set 11 | qasigiannguit
# Processing Record 12 of Set 11 | beziers
# Processing Record 13 of Set 11 | durazno
# Processing Record 14 of Set 11 | carballo
# Processing Record 15 of Set 11 | leua
# Processing Record 16 of Set 11 | tateyama
# Processing Record 17 of Set 11 | saint john
# Processing Record 18 of Set 11 | leh
# Processing Record 19 of Set 11 | vestmannaeyjar
# Processing Record 20 of Set 11 | garowe
# Processing Record 21 of Set 11 | pacific grove
# Processing Record 22 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 11 | alice springs
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | pisco
# Processing Record 26 of Set 11 | guicheng
# City not found. Skipping...
# Processing Record 27 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 11 | khed brahma
# Processing Record 29 of Set 11 | taksimo
# Processing Record 30 of Set 11 | zhongshu
# Processing Record 31 of Set 11 | taywarah
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | perundurai
# Processing Record 34 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 11 | troitsk
# Processing Record 36 of Set 11 | fairbanks
# Processing Record 37 of Set 11 | pangnirtung
# Processing Record 38 of Set 11 | sidi ali
# Processing Record 39 of Set 11 | sinnamary
# Processing Record 40 of Set 11 | kabakovo
# Processing Record 41 of Set 11 | vilhena
# Processing Record 42 of Set 11 | ozernovskiy
# Processing Record 43 of Set 11 | meulaboh
# Processing Record 44 of Set 11 | mindelo
# Processing Record 45 of Set 11 | alta
# Processing Record 46 of Set 11 | buala
# Processing Record 47 of Set 11 | dezhou
# Processing Record 48 of Set 11 | vinh
# Processing Record 49 of Set 11 | pavlodar
# Processing Record 50 of Set 11 | roma
# Processing Record 1 of Set 12 | gillette
# Processing Record 2 of Set 12 | chenzhou
# Processing Record 3 of Set 12 | key largo
# Processing Record 4 of Set 12 | hamilton
# Processing Record 5 of Set 12 | karpathos
# Processing Record 6 of Set 12 | berezovyy
# Processing Record 7 of Set 12 | kasongo-lunda
# Processing Record 8 of Set 12 | halifax
# Processing Record 9 of Set 12 | marystown
# Processing Record 10 of Set 12 | paracatu
# Processing Record 11 of Set 12 | bull savanna
# Processing Record 12 of Set 12 | beyneu
# Processing Record 13 of Set 12 | lumut
# Processing Record 14 of Set 12 | rafaela
# Processing Record 15 of Set 12 | baherden
# Processing Record 16 of Set 12 | laredo
# Processing Record 17 of Set 12 | santa isabel
# Processing Record 18 of Set 12 | karakulino
# Processing Record 19 of Set 12 | san juan
# Processing Record 20 of Set 12 | alta floresta
# Processing Record 21 of Set 12 | antsohihy
# Processing Record 22 of Set 12 | sambhal
# Processing Record 23 of Set 12 | riachao
# Processing Record 24 of Set 12 | pocatello
# Processing Record 25 of Set 12 | kanniyakumari
# Processing Record 26 of Set 12 | magdagachi
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | prince rupert
# Processing Record 29 of Set 12 | lincoln
# Processing Record 30 of Set 12 | padang
# Processing Record 31 of Set 12 | baker city
# Processing Record 32 of Set 12 | matagami
# Processing Record 33 of Set 12 | mangaratiba
# Processing Record 34 of Set 12 | runkel
# Processing Record 35 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 12 | alyangula
# Processing Record 37 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 12 | saint-francois
# Processing Record 39 of Set 12 | kizema
# Processing Record 40 of Set 12 | borba
# Processing Record 41 of Set 12 | bartica
# Processing Record 42 of Set 12 | hofn
# Processing Record 43 of Set 12 | freeport
# Processing Record 44 of Set 12 | straumen
# Processing Record 45 of Set 12 | abbeville
# Processing Record 46 of Set 12 | tandalti
# Processing Record 47 of Set 12 | barabinsk
# Processing Record 48 of Set 12 | kerema
# Processing Record 49 of Set 12 | kui buri
# Processing Record 50 of Set 12 | hrusovany nad jevisovkou
# Processing Record 1 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 13 | tevriz
# Processing Record 3 of Set 13 | murgab
# Processing Record 4 of Set 13 | mizdah
# Processing Record 5 of Set 13 | nelson bay
# Processing Record 6 of Set 13 | portage
# Processing Record 7 of Set 13 | larap
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | jambi
# Processing Record 10 of Set 13 | ancud
# Processing Record 11 of Set 13 | walvis bay
# Processing Record 12 of Set 13 | uruacu
# Processing Record 13 of Set 13 | zaraza
# Processing Record 14 of Set 13 | navalmoral de la mata
# Processing Record 15 of Set 13 | bend
# Processing Record 16 of Set 13 | joue-les-tours
# Processing Record 17 of Set 13 | kiunga
# Processing Record 18 of Set 13 | imbituba
# Processing Record 19 of Set 13 | talcahuano
# Processing Record 20 of Set 13 | lengshuitan
# Processing Record 21 of Set 13 | saint-augustin
# Processing Record 22 of Set 13 | westport
# Processing Record 23 of Set 13 | syamzha
# Processing Record 24 of Set 13 | lima
# Processing Record 25 of Set 13 | sabang
# Processing Record 26 of Set 13 | sindor
# Processing Record 27 of Set 13 | ko samui
# Processing Record 28 of Set 13 | tres arroyos
# Processing Record 29 of Set 13 | hambantota
# Processing Record 30 of Set 13 | vila velha
# Processing Record 31 of Set 13 | lalmohan
# Processing Record 32 of Set 13 | manado
# Processing Record 33 of Set 13 | garissa
# Processing Record 34 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 13 | panaba
# Processing Record 36 of Set 13 | lunenburg
# Processing Record 37 of Set 13 | suzu
# City not found. Skipping...
# Processing Record 38 of Set 13 | geneva
# Processing Record 39 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 13 | massa marittima
# Processing Record 41 of Set 13 | mandapam
# Processing Record 42 of Set 13 | bereda
# Processing Record 43 of Set 13 | felanitx
# Processing Record 44 of Set 13 | marsa matruh
# Processing Record 45 of Set 13 | lifford
# Processing Record 46 of Set 13 | coromandel
# Processing Record 47 of Set 13 | vryburg
# Processing Record 48 of Set 13 | sonari
# Processing Record 49 of Set 13 | rabo de peixe
# Processing Record 50 of Set 13 | lencois paulista
# Processing Record 1 of Set 14 | peachtree city
# Processing Record 2 of Set 14 | zyryanskoye
# Processing Record 3 of Set 14 | qafsah
# City not found. Skipping...
# Processing Record 4 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 5 of Set 14 | strangnas
# Processing Record 6 of Set 14 | bathsheba
# Processing Record 7 of Set 14 | cape canaveral
# Processing Record 8 of Set 14 | zyryanovsk
# Processing Record 9 of Set 14 | lata
# Processing Record 10 of Set 14 | ejura
# Processing Record 11 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 14 | taseyevo
# Processing Record 13 of Set 14 | moerai
# Processing Record 14 of Set 14 | tshela
# Processing Record 15 of Set 14 | show low
# Processing Record 16 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 17 of Set 14 | tongren
# Processing Record 18 of Set 14 | inirida
# Processing Record 19 of Set 14 | eyl
# Processing Record 20 of Set 14 | narsaq
# Processing Record 21 of Set 14 | coahuayana
# Processing Record 22 of Set 14 | bonfim
# Processing Record 23 of Set 14 | paracale
# Processing Record 24 of Set 14 | zhigansk
# Processing Record 25 of Set 14 | visp
# Processing Record 26 of Set 14 | sambava
# Processing Record 27 of Set 14 | souillac
# Processing Record 28 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 14 | mackay
# Processing Record 31 of Set 14 | russell
# Processing Record 32 of Set 14 | madison
# Processing Record 33 of Set 14 | summerville
# Processing Record 34 of Set 14 | thongwa
# Processing Record 35 of Set 14 | port macquarie
# Processing Record 36 of Set 14 | casino
# Processing Record 37 of Set 14 | nishihara
# Processing Record 38 of Set 14 | axim
# Processing Record 39 of Set 14 | nongan
# Processing Record 40 of Set 14 | totness
# Processing Record 41 of Set 14 | nurota
# Processing Record 42 of Set 14 | payo
# Processing Record 43 of Set 14 | panalingaan
# Processing Record 44 of Set 14 | morrope
# Processing Record 45 of Set 14 | zlynka
# Processing Record 46 of Set 14 | paka
# Processing Record 47 of Set 14 | dabhol
# Processing Record 48 of Set 14 | kothapet
# Processing Record 49 of Set 14 | ialibu
# Processing Record 50 of Set 14 | kantang
# Processing Record 1 of Set 15 | playa vicente
# Processing Record 2 of Set 15 | margate
# Processing Record 3 of Set 15 | custoias
# Processing Record 4 of Set 15 | manzhouli
# Processing Record 5 of Set 15 | paranaiba
# Processing Record 6 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 15 | doctor juan leon mallorquin
# Processing Record 8 of Set 15 | adamovka
# Processing Record 9 of Set 15 | salinopolis
# Processing Record 10 of Set 15 | tuatapere
# Processing Record 11 of Set 15 | saint-louis
# Processing Record 12 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 15 | aras
# Processing Record 14 of Set 15 | ngong
# Processing Record 15 of Set 15 | loma alta
# Processing Record 16 of Set 15 | kandrian
# Processing Record 17 of Set 15 | marawi
# Processing Record 18 of Set 15 | dubti
# Processing Record 19 of Set 15 | galveston
# Processing Record 20 of Set 15 | young
# Processing Record 21 of Set 15 | moanda
# Processing Record 22 of Set 15 | stuartfield
# Processing Record 23 of Set 15 | kangaatsiaq
# Processing Record 24 of Set 15 | kamarion
# Processing Record 25 of Set 15 | maxixe
# Processing Record 26 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 27 of Set 15 | tura
# Processing Record 28 of Set 15 | tecoanapa
# Processing Record 29 of Set 15 | rybachiy
# Processing Record 30 of Set 15 | kapit
# Processing Record 31 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 32 of Set 15 | palu
# Processing Record 33 of Set 15 | wiang sa
# Processing Record 34 of Set 15 | lasem
# Processing Record 35 of Set 15 | marfino
# Processing Record 36 of Set 15 | nenjiang
# Processing Record 37 of Set 15 | arona
# Processing Record 38 of Set 15 | tarko-sale
# Processing Record 39 of Set 15 | altonia
# City not found. Skipping...
# Processing Record 40 of Set 15 | taman
# Processing Record 41 of Set 15 | dafeng
# Processing Record 42 of Set 15 | flinders
# Processing Record 43 of Set 15 | san rafael
# Processing Record 44 of Set 15 | zhangjiakou
# Processing Record 45 of Set 15 | gundlupet
# Processing Record 46 of Set 15 | kuzedeyevo
# Processing Record 47 of Set 15 | petrivka
# Processing Record 48 of Set 15 | mao
# Processing Record 49 of Set 15 | malinovoye ozero
# Processing Record 50 of Set 15 | boende
# Processing Record 1 of Set 16 | dwarka
# Processing Record 2 of Set 16 | siva
# Processing Record 3 of Set 16 | nazas
# Processing Record 4 of Set 16 | matay
# Processing Record 5 of Set 16 | cazaje
# City not found. Skipping...
# Processing Record 6 of Set 16 | launceston
# Processing Record 7 of Set 16 | kalmar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura -46.1927  168.8643     61.48        96         100
# 1        Artigas -30.4000  -56.4667     91.27        18           0
# 2      Jamestown  42.0970  -79.2353     17.53        44          20
# 3      Busselton -33.6500  115.3333     66.04        89           0
# 4        Rikitea -23.1203 -134.9692     77.29        74         100
# 5       Olafsvik  64.8945  -23.7142     38.41        70         100
# 6      Kavaratti  10.5669   72.6420     80.85        73          72
# 7  Batagay-Alyta  67.8006  130.4114    -19.48        95          58
# 8      Athabasca  54.7169 -113.2854     35.42        89          17
# 9        Ushuaia -54.8000  -68.3000     55.06        76          75
#
#    Wind Speed Current Description Country                 Date
# 0        1.88     overcast clouds      NZ  2022-01-29 18:35:16
# 1       12.53           clear sky      UY  2022-01-29 18:35:16
# 2        4.00          few clouds      US  2022-01-29 18:35:17
# 3       15.55           clear sky      AU  2022-01-29 18:35:17
# 4       12.80          light rain      PF  2022-01-29 18:35:18
# 5       27.18     overcast clouds      IS  2022-01-29 18:30:34
# 6        6.06       broken clouds      IN  2022-01-29 18:35:18
# 7        5.14       broken clouds      RU  2022-01-29 18:35:19
# 8        3.24          few clouds      CA  2022-01-29 18:31:04
# 9       13.80             drizzle      AR  2022-01-29 18:32:15

# %%
# #Reorder Columns
new_column_order=["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")

# %%
#Load csv
file_to_load = "weather_data/WeatherPy_Database.csv"

#Read csv
city_data_df = pd.read_csv(file_to_load)
city_data_df
# Out:
#      City_ID  Unnamed: 0        City Country                 Date      Lat  \
# 0          0           0     Mataura      NZ  2022-01-29 18:35:16 -46.1927
# 1          1           1     Artigas      UY  2022-01-29 18:35:16 -30.4000
# 2          2           2   Jamestown      US  2022-01-29 18:35:17  42.0970
# 3          3           3   Busselton      AU  2022-01-29 18:35:17 -33.6500
# 4          4           4     Rikitea      PF  2022-01-29 18:35:18 -23.1203
# ..       ...         ...         ...     ...                  ...      ...
# 689      689         689        Siva      EG  2022-01-29 18:40:59  29.2041
# 690      690         690       Nazas      MX  2022-01-29 18:40:59  25.2333
# 691      691         691       Matay      EG  2022-01-29 18:39:31  28.4190
# 692      692         692  Launceston      AU  2022-01-29 18:41:00 -41.4500
# 693      693         693      Kalmar      SE  2022-01-29 18:41:00  56.6616
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0    168.8643     61.48        96         100        1.88     overcast clouds
# 1    -56.4667     91.27        18           0       12.53           clear sky
# 2    -79.2353     17.53        44          20        4.00          few clouds
# 3    115.3333     66.04        89           0       15.55           clear sky
# 4   -134.9692     77.29        74         100       12.80          light rain
# ..        ...       ...       ...         ...         ...                 ...
# 689   25.5195     55.53        53          13        8.48          few clouds
# 690 -104.1333     59.61        46           0        4.70           clear sky
# 691   30.7792     51.49        47           0        4.97           clear sky
# 692  147.1667     58.64        77          40       13.80    scattered clouds
# 693   16.3616     46.33        86          75       21.85       broken clouds
#
# [694 rows x 12 columns]
